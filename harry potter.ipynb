# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("books.csv")
ds
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
ds.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %%
null_values = ds.isnull().sum()

# Display the number of null values
null_values
# Out:
# book_id                        0
# goodreads_book_id              0
# best_book_id                   0
# work_id                        0
# books_count                    0
# isbn                          52
# isbn13                        44
# authors                        0
# original_publication_year      3
# original_title                52
# title                          0
# language_code                109
# average_rating                 0
# ratings_count                  0
# work_ratings_count             0
# work_text_reviews_count        0
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# image_url                      0
# small_image_url                0
# dtype: int64

# %%
cleaned_ds = ds.dropna()

# %%
cleaned_ds
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
null_values = cleaned_ds.isnull().sum()
null_values
# Out:
# book_id                      0
# goodreads_book_id            0
# best_book_id                 0
# work_id                      0
# books_count                  0
# isbn                         0
# isbn13                       0
# authors                      0
# original_publication_year    0
# original_title               0
# title                        0
# language_code                0
# average_rating               0
# ratings_count                0
# work_ratings_count           0
# work_text_reviews_count      0
# ratings_1                    0
# ratings_2                    0
# ratings_3                    0
# ratings_4                    0
# ratings_5                    0
# image_url                    0
# small_image_url              0
# dtype: int64

# %%
cleaned_ds.drop(columns=['small_image_url', 'image_url', 'original_title', 'book_id','goodreads_book_id','best_book_id','work_id','isbn','isbn13'], inplace=True)

# %%
cleaned_ds
# Out:
#       books_count                      authors  original_publication_year  \
# 0             272              Suzanne Collins                     2008.0
# 1             491  J.K. Rowling, Mary GrandPré                     1997.0
# 2             226              Stephenie Meyer                     2005.0
# 3             226                   John Green                     2012.0
# 4             210                Veronica Roth                     2011.0
# ...           ...                          ...                        ...
# 1349           52                 Mary Hoffman                     2002.0
# 1350           22            Caragh M. O'Brien                     2012.0
# 1351           18  Abigail Haas, Abby McDonald                     2013.0
# 1352           19        Maria Dahvana Headley                     2015.0
# 1353           25               Simone Elkeles                     2013.0
#
#                                                   title language_code  \
# ...

# %%
# Basic statistics
cleaned_ds.describe()
# Out:
#        books_count  original_publication_year  average_rating  ratings_count  \
# count  1153.000000                1153.000000     1153.000000   1.153000e+03
# mean     52.777103                2003.698179        3.992819   1.014850e+05
# std      64.054893                  15.992755        0.223829   3.095194e+05
# min       2.000000                1871.000000        3.230000   8.861000e+03
# 25%      24.000000                2003.000000        3.840000   1.858300e+04
# 50%      38.000000                2008.000000        4.000000   3.139500e+04
# 75%      61.000000                2011.000000        4.150000   6.682300e+04
# max    1314.000000                2017.000000        4.740000   4.780653e+06
#
#        work_ratings_count  work_text_reviews_count      ratings_1  \
# count        1.153000e+03              1153.000000    1153.000000
# mean         1.097655e+05              5621.572420    2555.634866
# std          3.258908e+05             11410.001335   14830.209633
# ...

# %%
#Calculate total ratings count for each book
cleaned_ds['total_ratings'] = cleaned_ds['ratings_1'] + cleaned_ds['ratings_2'] + cleaned_ds['ratings_3'] + cleaned_ds['ratings_4'] + cleaned_ds['ratings_5']

# Sort the dataset by total ratings in descending order
most_selling_books = cleaned_ds[['title', 'total_ratings']].sort_values(by='total_ratings', ascending=False)

print("Top 5 most selling books within the Harry Potter series:")
print(most_selling_books.head(20))
# Out:
# C:\Users\win 10\AppData\Local\Temp\ipykernel_264\652562825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_ds['total_ratings'] = cleaned_ds['ratings_1'] + cleaned_ds['ratings_2'] + cleaned_ds['ratings_3'] + cleaned_ds['ratings_4'] + cleaned_ds['ratings_5']
# Top 5 most selling books within the Harry Potter series:
#                                                 title  total_ratings
# 0             The Hunger Games (The Hunger Games, #1)        4942365
# 1   Harry Potter and the Sorcerer's Stone (Harry P...        4800065
# 2                             Twilight (Twilight, #1)        3916824
# 3                              The Fault in Our Stars        2478609
# ...

# %%
# Calculate the average rating of the Harry Potter books
average_rating = cleaned_ds['average_rating'].mean()
print("\nAverage rating of the Harry Potter books:", average_rating)
# Out:
# Average rating of the Harry Potter books: 3.992818733738074
